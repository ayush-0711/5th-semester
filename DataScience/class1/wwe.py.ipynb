# %%
import pandas as pd
from pandas import Series, DataFrame
wwe_df = pd.read_csv("WWE Royal Rumble 1988-2017.csv")

# %% [markdown]
# # Features
# Columns Are called features, part of feature engineering
# # DataFrame
# Data structure in memory used for retrieving csv(dataset)

# %%
# get titanic & test csv files as a pandas DataFrame

print("......Printing the WWE DataFrame completely.....")
wwe_df
# Out:
# ......Printing the WWE DataFrame completely.....
#     Year  Royal Rumble                                              Venue  \
# 0   1988  Royal Rumble                                     Copps Coliseum
# 1   1989  Royal Rumble                                         The Summit
# 2   1990  Royal Rumble                                      Orlando Arena
# 3   1991  Royal Rumble                                        Miami Arena
# 4   1992  Royal Rumble                                Knickerbocker Arena
# 5   1993  Royal Rumble                                         ARCO Arena
# 6   1994  Royal Rumble                            Providence Civic Center
# 7   1995  Royal Rumble                                       USF Sun Dome
# 8   1996  Royal Rumble                                      Selland Arena
# 9   1997  Royal Rumble                                          Alamodome
# 10  1998  Royal Rumble                                     San Jose Arena
# ...

# %%
print(".............Printing the Info.....")
wwe_df.info()
# Out:
# .............Printing the Info.....
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 14 columns):
# Year                           30 non-null int64
# Royal Rumble                   30 non-null object
# Venue                          30 non-null object
# City                           30 non-null object
# State                          30 non-null object
# Country                        30 non-null object
# Attendance                     30 non-null object
# Royal Rumble Match             30 non-null object
# Winner                         30 non-null object
# Winner's Number                30 non-null int64
# Last Elimination               30 non-null object
# Total Royal Rumble Wins        30 non-null int64
# Number of Eliminations Made    30 non-null int64
# Match Length                   30 non-null object
# dtypes: int64(4), object(10)
# memory usage: 2.1+ KB

# %%
print("........Describing.....")
wwe_df.describe()
# Out:
# ........Describing.....
#               Year  Winner's Number  Total Royal Rumble Wins  \
# count    30.000000        30.000000                30.000000
# mean   2002.500000        20.166667                 1.300000
# std       8.803408        10.638522                 0.534983
# min    1988.000000         1.000000                 1.000000
# 25%    1995.250000        14.250000                 1.000000
# 50%    2002.500000        24.000000                 1.000000
# 75%    2009.750000        27.750000                 1.750000
# max    2017.000000        38.000000                 3.000000
#
#        Number of Eliminations Made
# count                    30.000000
# mean                      4.733333
# std                       2.405931
# min                       1.000000
# 25%                       3.000000
# 50%                       4.000000
# 75%                       6.000000
# max                      10.000000

# %%
pd.Index?

# %%
dir(pd)
# Out:
# ['Categorical',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'ExcelFile',
#  'ExcelWriter',
#  'Expr',
#  'Float64Index',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int64Index',
#  'Interval',
#  'IntervalIndex',
#  'MultiIndex',
#  'NaT',
#  'Panel',
#  'Panel4D',
#  'Period',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseArray',
#  'SparseDataFrame',
#  'SparseList',
#  'SparseSeries',
#  'Term',
#  'TimeGrouper',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt64Index',
#  'WidePanel',
#  '_DeprecatedModule',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_hashtable',
#  '_lib',
#  '_libs',
#  '_np_version_under1p10',
#  '_np_version_under1p11',
#  '_np_version_under1p12',
#  '_np_version_under1p13',
#  '_np_version_under1p14',
#  '_np_version_under1p8',
# ...

# %%
wwe_df.head().plot()

# %%
dir(pd)
# Out:
# ['Categorical',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'ExcelFile',
#  'ExcelWriter',
#  'Expr',
#  'Float64Index',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int64Index',
#  'Interval',
#  'IntervalIndex',
#  'MultiIndex',
#  'NaT',
#  'Panel',
#  'Panel4D',
#  'Period',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseArray',
#  'SparseDataFrame',
#  'SparseList',
#  'SparseSeries',
#  'Term',
#  'TimeGrouper',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt64Index',
#  'WidePanel',
#  '_DeprecatedModule',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_hashtable',
#  '_lib',
#  '_libs',
#  '_np_version_under1p10',
#  '_np_version_under1p11',
#  '_np_version_under1p12',
#  '_np_version_under1p13',
#  '_np_version_under1p14',
#  '_np_version_under1p8',
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
x=pd.to_datetime(wwe_df["Year"])
y=wwe_df["Attendance"]
#plt.plot(x,y)
#plt.show()

#wwe_df["Country"].unique()
sns.lmplot("Year","Attendance", data=wwe_df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.4/dist-packages/pandas/core/nanops.py in _ensure_numeric(x)
#     767         try:
# --> 768             x = float(x)
#     769         except Exception:
#
# ValueError: could not convert string to float: '18,00019,00018,00016,00017,00016,00014,50010,0009,60060,47718,54214,81619,23117,13716,10615,33817,28912,00016,00013,50020,79816,68516,69715,11318,12115,10315,71517,16415,17052,020'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.4/dist-packages/pandas/core/nanops.py in _ensure_numeric(x)
#     770             try:
# --> 771                 x = complex(x)
#     772             except Exception:
#
# ValueError: complex() arg is a malformed string
#
# ...

# %%
help(pd.to_datetime)
# Out:
# Help on function to_datetime in module pandas.core.tools.datetimes:
#
# to_datetime(arg, errors='raise', dayfirst=False, yearfirst=False, utc=None, box=True, format=None, exact=True, unit=None, infer_datetime_format=False, origin='unix')
#     Convert argument to datetime.
#
#     Parameters
#     ----------
#     arg : integer, float, string, datetime, list, tuple, 1-d array, Series
#
#         .. versionadded: 0.18.1
#
#            or DataFrame/dict-like
#
#     errors : {'ignore', 'raise', 'coerce'}, default 'raise'
#
#         - If 'raise', then invalid parsing will raise an exception
#         - If 'coerce', then invalid parsing will be set as NaT
#         - If 'ignore', then invalid parsing will return the input
#     dayfirst : boolean, default False
#         Specify a date parse order if `arg` is str or its list-likes.
#         If True, parses dates with the day first, eg 10/11/12 is parsed as
#         2012-11-10.
# ...
